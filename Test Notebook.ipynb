# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = [1, 3, 4, 3, 2, 2, 1, 4, 4, 4, 5, 1]

# %%
print(np.mean(data))
print(np.var(data))
# Out:
# 2.8333333333333335
# 1.8055555555555554

# %%
plt.plot(data)

# %%
transformed_data = [(point - 2) ** 3 for point in data]

# %%
plt.plot(transformed_data)
