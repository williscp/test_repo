# %%
import numpy as np
import matplotlib.pyplot as plt
import os 
import jpeg

# %%
# Added more additional data to end
data = [1, 3, 4, 3, 2, 2, 1, 4, 4, 4, 5, 1, 3, 4, 5, 2, 3, ]

# %%
# add some comments
print(np.mean(data))
# add some comments
print(np.var(data))
# add some comments
print(data)
# Out:
# 2.8333333333333335
# 1.8055555555555554
# [1, 3, 4, 3, 2, 2, 1, 4, 4, 4, 5, 1]

# %%
# Added argument to method call
plt.plot(data, 'r')
# plot changed

# %%
# added new lines
transformed_data = [(point - 2) for point in data]
transformed_data = [(point ** 3) for point in transformed_data]
# removed lines

# %%
plt.plot(transformed_data)
